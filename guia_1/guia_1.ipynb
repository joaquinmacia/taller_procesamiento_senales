# %% [markdown]
# # GUIA 1

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# ![image.png](enunciados/ej1.png)

# %%
# Cargamos la imagen
imagen = mpimg.imread('enunciados/pikachu_vs_charmander.jpeg')
# Mostramos la imagen
plt.imshow(imagen)
plt.axis('off')  # Oculta los ejes
plt.show()

# %%
# a)
imagen_r = imagen [:,:,0]
imagen_g = imagen [:,:,1]
imagen_b = imagen [:,:,2]

imagen_bw1 = (np.min([imagen_r,imagen_g,imagen_b], axis=0) + np.max([imagen_r,imagen_g,imagen_b], axis=0)) / 2

plt.imshow(imagen_bw1, cmap='gray')
plt.axis('off')  # Oculta los ejes
plt.show()
# Out:
# (-0.5, 340.5, 255.5, -0.5)

# %%
# b)

imagen_bw2 = (imagen_r + imagen_g + imagen_b) / 3
plt.imshow(imagen_bw2, cmap='gray')
plt.axis('off')  # Oculta los ejes
plt.show()
# Out:
# (-0.5, 340.5, 255.5, -0.5)

# %%
# c)
imagen_bw3 =
